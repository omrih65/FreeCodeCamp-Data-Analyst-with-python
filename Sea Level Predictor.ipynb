# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

def draw_plot():
    # Read data from file
    try:
        data = pd.read_csv("epa-sea-level.csv")
    except:
        print('Erorr')
    # Create scatter plot
    fig, ax = plt.subplots()
    plt.scatter(x = data['Year'], y = data['CSIRO Adjusted Sea Level'])

    # Create first line of best fit
    res = linregress(data['Year'], data['CSIRO Adjusted Sea Level'])
    x_pred = pd.Series(range(1880,2051))
    y_pred = res.intercept + res.slope * x_pred
    plt.plot(x_pred, y_pred ,label='fitted line')
    
    # Create second line of best fit
    data_2000 = data[data[data['Year'] == 2000].index[0] : ]
    res = linregress(data_2000['Year'], data_2000['CSIRO Adjusted Sea Level'])
    x_pred2 = pd.Series(range(2000,2051))
    y_pred2 = res.intercept + res.slope*x_pred2
    plt.plot(x_pred2, y_pred2, label='fitted line')
    # Add labels and title
    ax.set_xlabel('Year')
    ax.set_ylabel('Sea Level (inches)')
    ax.set_title('Rise in Sea Level')
    
    # Save plot and return data for testing (DO NOT MODIFY)
    plt.savefig('sea_level_plot.png')
    return plt.gca()

# %%
data = pd.read_csv("epa-sea-level.csv")
data
# Out:
#      Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0    1880                  0.000000          -0.952756           0.952756
# 1    1881                  0.220472          -0.732283           1.173228
# 2    1882                 -0.440945          -1.346457           0.464567
# 3    1883                 -0.232283          -1.129921           0.665354
# 4    1884                  0.590551          -0.283465           1.464567
# ..    ...                       ...                ...                ...
# 129  2009                  8.586614           8.311024           8.862205
# 130  2010                  8.901575           8.618110           9.185039
# 131  2011                  8.964567           8.661417           9.267717
# 132  2012                  9.326772           8.992126           9.661417
# 133  2013                  8.980315           8.622047           9.338583
#
#      NOAA Adjusted Sea Level
# 0                        NaN
# ...

# %%
# Read data from file
try:
    data = pd.read_csv("epa-sea-level.csv")
except:
    print('Erorr')
# Create scatter plot
fig, ax = plt.subplots()
plt.scatter(x = data['Year'], y = data['CSIRO Adjusted Sea Level'])

    # Create first line of best fit
res = linregress(data['Year'], data['CSIRO Adjusted Sea Level'])
x_pred = pd.Series(range(1880,2050))
y_pred = res.intercept + res.slope * x_pred
plt.plot(x_pred, y_pred ,label='fitted line')
    
    # Create second line of best fit
data_2000 = data[data[data['Year'] == 2000].index[0] : ]
res2 = linregress(data_2000['Year'], data_2000['CSIRO Adjusted Sea Level'])
x_pred2 = pd.Series(range(2000,2050))
y_pred2 = res.intercept + res.slope*x_pred2
plt.plot(x_pred2, y_pred2, label='fitted line')
    # Add labels and title
ax.set_xlabel('Year')
ax.set_ylabel('Sea Level (inches)')
ax.set_title('Rise in Sea Level')
# Out:
# Text(0.5, 1.0, 'Rise in Sea Level')
